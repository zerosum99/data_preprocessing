# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10, 100)

# %%
y = np.cos(x)

# %%
z = np.sin(x)

# %%
data = 2 * np.random.random((10, 10)) 
data2 = 3 * np.random.random((10, 10))

# %%
data.shape
# Out:
# (10, 10)

# %%
data2.shape
# Out:
# (10, 10)

# %%
Y, X = np.mgrid[-3:3:100j, -3:3:100j]

# %%
Y.shape
# Out:
# (100, 100)

# %%
X.shape
# Out:
# (100, 100)

# %%
U = -1 - X**2 + Y 
V = 1 + X - Y**2

# %%
fig5, axes = plt.subplots(nrows=2,ncols=2)
axes[0,1].streamplot(X,Y,U,V)  # lot 2D vector fields 
axes[1,1].quiver(y,z)         #  Plot a 2D field of arrows 
plt.show()

# %%
from matplotlib.cbook import get_sample_data

# %%
help(get_sample_data)
# Out:
# Help on function get_sample_data in module matplotlib.cbook:
#
# get_sample_data(fname, asfileobj=True)
#     Return a sample data file.  *fname* is a path relative to the
#     `mpl-data/sample_data` directory.  If *asfileobj* is `True`
#     return a file object, otherwise just a file path.
#
#     Set the rc parameter examples.directory to the directory where we should
#     look, if sample_data files are stored in a location different than
#     default (which is 'mpl-data/sample_data` at the same level of 'matplotlib`
#     Python module files).
#
#     If the filename ends in .gz, the file is implicitly ungzipped.

# %%
img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %%
img.shape
# Out:
# (15, 15)

# %%
fig, ax = plt.subplots() 
im = ax.imshow(img,             # Colormapped or RGB arrays      
               cmap='gist_earth',         
               interpolation='nearest',           
               vmin=-2,           
               vmax=2) 
fig.colorbar(im, orientation='horizontal')

# %%
fig5, axes2 = plt.subplots(nrows=2,ncols=1)

axes2[0].pcolor(data2)       #Pseudocolor plot of 2D array 
axes2[0].pcolormesh(data)    #Pseudocolor plot of 2D arra

# %%
fig5, axes2 = plt.subplots(nrows=2,ncols=1)

axes2[0].pcolor(data2)       #Pseudocolor plot of 2D array 
axes2[0].pcolormesh(data)    #Pseudocolor plot of 2D array 
CS = plt.contour(Y,X,U)      #Plot contours

# %%
fig5, axes2 = plt.subplots(nrows=2,ncols=1)

axes2[0].pcolor(data2)       #Pseudocolor plot of 2D array 
axes2[0].pcolormesh(data)    #Pseudocolor plot of 2D array 
CS = plt.contour(Y,X,U)      #Plot contours 
axes2[1].contourf(data)     #Plot filled contours 
axes2[1]= ax.clabel(CS)      #Label a contour plot

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## 그래프의 구조

# %%
from IPython.display import Image
Image("figure_axes.png")

# %% [markdown]
# ## 1. figure와 axes 알아보기

# %% [markdown]
# ### 1.1 피겨만 생성해보기

# %%
fig_ = plt.figure()

# %%
fig_.get_axes()
# Out:
# []

# %%
fig_.add_subplot(221)

# %%
fig_.get_axes()

# %%
ax_ = fig_.get_axes()

# %%
ax_[0]

# %%
a =  ax_[0].plot([1,2,3,4])

# %%
a
plt.show()

# %% [markdown]
# ### 그래프를 출력하려면 하나의 셀에 표시해서 처리

# %%
fig_ = plt.figure()
fig_.add_subplot(221)

ax_ = fig_.get_axes()
ax_[0].plot([1,2,3,4])
plt.show()

# %% [markdown]
# ### 1.2 axes 만 생성하기

# %%
ax = plt.axes()

# %%
ax

# %% [markdown]
# ### 피겨 생성과 axes 생성한 피겨 비교하기

# %%
fig_1 = ax.get_figure()

# %%
fig_ is fig_1
# Out:
# False

# %% [markdown]
# # 2. axes 알아보기

# %%
ax1 = plt.axes()  # standard axes
plt.show()

# %% [markdown]
# ### 내부에 axes 그리기
#
#    [left, bottom, width, height]

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# ### 그래프를 그려서 보려면 하나의 셀에 그래프를 표시해서 처리해야 함

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])
ax1.plot([1,2,3,4])
ax2.plot([1,2,3,4])
plt.show()

# %% [markdown]
# ## 3. add_axes 알아보기

# %% [markdown]
# ### 두개의 그래프가 들어갈 공간을 만들기

# %%
fig = plt.figure()

# %%
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

# %% [markdown]
# #### 두 개의 그래프 그리기

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# ## 4. subplots 함수 알아보기

# %% [markdown]
# ### : Simple Grids of Subplots

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %% [markdown]
# ##  The Whole Grid in One Go

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %% [markdown]
# ### axex를 이용해서 텍스트 넣기

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
        
fig

# %% [markdown]
# ### 간격 조정하기

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)  # plt.subplots_adjust는 이러한 플롯 간의 간격을 조정하는 데 사용할 수 있습니다.

for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %% [markdown]
#  ### More Complicated Arrangements

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

# %%
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %% [markdown]
# ## 5. 전체 예시

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()
